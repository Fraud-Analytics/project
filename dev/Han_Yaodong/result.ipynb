# %%
from collections import ChainMap
from collections import defaultdict

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

from util import load_data, fdr, plot_report
pd.set_option('display.max_rows', 100)

# %%
x_train, x_test, x_oot, y_train, y_test, y_oot = load_data('var_30.csv')
x_train.head()
# Out:
#         ssn_count_3  fulladdress_count_0  address_count_0  name_dob_count_3  \
# 581748    -0.047591            -0.041351        -0.042158         -0.046415
# 72180     -0.047591            -0.041351        -0.042158         -0.046415
# 212705    -0.047591            -0.041351        -0.042158         -0.046415
# 644881    -0.047591            -0.041351        -0.042158         -0.046415
# 578692    -0.047591            -0.041351        -0.042158         -0.046415
#
#         homephone_count_14  name_dob_count_7  name_day_since  \
# 581748            1.282153         -0.055801       -1.756544
# 72180            -0.437943         -0.055801        0.598116
# 212705            0.135423         -0.055801       -1.845961
# 644881           -0.437943         -0.055801       -1.875767
# 578692            0.135423         -0.055801       -1.920476
#
#         ssn_firstname_count_0_by_14  name_count_7  \
# 581748                     0.123528     -0.115648
# 72180                      0.123528     -0.115648
# 212705                     0.123528     -0.115648
# 644881                     0.123528     -0.115648
# 578692                     0.123528     -0.115648
#
#         fulladdress_homephone_count_0_by_14  ...  ssn_count_0_by_14  \
# 581748                             0.120387  ...           0.124781
# 72180                              0.120387  ...           0.124781
# 212705                             0.120387  ...           0.124781
# 644881                             0.120387  ...           0.124781
# 578692                             0.120387  ...           0.124781
#
#         ssn_firstname_count_7  ssn_count_7  fulladdress_count_1_by_14  \
# 581748              -0.057185    -0.058092                   0.123861
# 72180               -0.057185    -0.058092                   0.123861
# 212705              -0.057185    -0.058092                   0.123861
# 644881              -0.057185    -0.058092                   0.123861
# 578692              -0.057185    -0.058092                   0.123861
#
#         fulladdress_homephone_count_7  ssn_name_dob_count_7  name_count_14  \
# 581748                      -0.057263             -0.055635      -0.159376
# 72180                       -0.057263             -0.055635      -0.159376
# 212705                      -0.057263             -0.055635      -0.159376
# 644881                      -0.057263             -0.055635      -0.159376
# 578692                      -0.057263             -0.055635      -0.159376
#
#         ssn_firstname_count_0_by_30  ssn_lastname_count_0_by_30  ssn_count_14
# 581748                     0.171472                    0.171458     -0.072421
# 72180                      0.171472                    0.171458     -0.072421
# 212705                     0.171472                    0.171458     -0.072421
# 644881                     0.171472                    0.171458     -0.072421
# 578692                     0.171472                    0.171458     -0.072421
#
# [5 rows x 30 columns]

# %%
rf = RandomForestClassifier(n_estimators=150,
                            max_depth=20,
                            max_features=10,
                            ccp_alpha=1e-6,
                            min_samples_leaf=2,
                            n_jobs=8).fit(x_train, y_train)

# %%
def generate_report(clf, x, y):
    y_prob = clf.predict_proba(x)[:, -1:]
    num_total_fraud = len(y[y==1])
    num_total_record = len(y)
    num_records = int(0.01 * num_total_record)

    sorted_prob = np.asarray(sorted(zip(y_prob, y), key=lambda x: x[0], reverse=True))

    stat = defaultdict(list)
    for i in range(20):
        cutoff_bin = sorted_prob[i*num_records: (i+1)*num_records, 1:]
        stat['records'].append(num_records)
        stat['bads'].append(len(cutoff_bin[cutoff_bin==1]))
        if i == 0:
            stat['total_records'].append(stat['records'][0])
            stat['total_bads'].append(stat['bads'][0])
        else:
            stat['total_records'].append(stat['records'][i] + stat['total_records'][i-1])
            stat['total_bads'].append(stat['bads'][i] + stat['total_bads'][i-1])

    stat = pd.DataFrame(stat)
    stat['percentile_bin'] = range(1, 21)
    stat.set_index('percentile_bin', inplace=True)
    stat['goods'] = stat.records - stat.bads
    stat['percent_goods'] = (stat.goods / stat.records * 100).round(2)
    stat['percent_bads'] = 100 - stat.percent_goods

    stat['total_goods'] = stat.total_records - stat.total_bads
    stat['percent_total_bads'] = (stat.total_bads / num_total_fraud * 100).round(2)
    stat['percent_total_goods'] = (stat.total_goods / (num_total_record - num_total_fraud) * 100).round(2)
    
    cols = ['records', 'goods', 'bads', 'percent_goods', 'percent_bads',
            'total_records', 'total_goods', 'total_bads',
            'percent_total_goods', 'percent_total_bads']
    return stat[cols]

# %%
generate_report(rf, x_train, y_train)
# Out:
#                 records  goods  bads  percent_goods  percent_bads  \
# percentile_bin
# 1                  6400   1541  4859          24.08         75.92
# 2                  6400   6228   172          97.31          2.69
# 3                  6400   6326    74          98.84          1.16
# 4                  6400   6334    66          98.97          1.03
# 5                  6400   6347    53          99.17          0.83
# 6                  6400   6349    51          99.20          0.80
# 7                  6400   6351    49          99.23          0.77
# 8                  6400   6350    50          99.22          0.78
# 9                  6400   6343    57          99.11          0.89
# 10                 6400   6348    52          99.19          0.81
# 11                 6400   6361    39          99.39          0.61
# 12                 6400   6336    64          99.00          1.00
# 13                 6400   6340    60          99.06          0.94
# 14                 6400   6373    27          99.58          0.42
# 15                 6400   6364    36          99.44          0.56
# 16                 6400   6356    44          99.31          0.69
# 17                 6400   6358    42          99.34          0.66
# 18                 6400   6349    51          99.20          0.80
# 19                 6400   6353    47          99.27          0.73
# 20                 6400   6343    57          99.11          0.89
#
#                 total_records  total_goods  total_bads  percent_total_goods  \
# percentile_bin
# 1                        6400         1541        4859                 0.24
# 2                       12800         7769        5031                 1.23
# 3                       19200        14095        5105                 2.23
# 4                       25600        20429        5171                 3.24
# 5                       32000        26776        5224                 4.24
# 6                       38400        33125        5275                 5.25
# 7                       44800        39476        5324                 6.26
# 8                       51200        45826        5374                 7.26
# 9                       57600        52169        5431                 8.27
# 10                      64000        58517        5483                 9.28
# 11                      70400        64878        5522                10.28
# 12                      76800        71214        5586                11.29
# 13                      83200        77554        5646                12.29
# 14                      89600        83927        5673                13.30
# 15                      96000        90291        5709                14.31
# 16                     102400        96647        5753                15.32
# 17                     108800       103005        5795                16.33
# 18                     115200       109354        5846                17.34
# 19                     121600       115707        5893                18.34
# 20                     128000       122050        5950                19.35
#
#                 percent_total_bads
# percentile_bin
# 1                            52.87
# 2                            54.74
# 3                            55.54
# 4                            56.26
# 5                            56.84
# 6                            57.39
# 7                            57.93
# 8                            58.47
# 9                            59.09
# 10                           59.66
# 11                           60.08
# 12                           60.78
# 13                           61.43
# 14                           61.72
# 15                           62.12
# 16                           62.59
# 17                           63.05
# 18                           63.61
# 19                           64.12
# 20                           64.74

# %%
generate_report(rf, x_test, y_test)
# Out:
#                 records  goods  bads  percent_goods  percent_bads  \
# percentile_bin
# 1                  1600    408  1192          25.50         74.50
# 2                  1600   1565    35          97.81          2.19
# 3                  1600   1579    21          98.69          1.31
# 4                  1600   1589    11          99.31          0.69
# 5                  1600   1586    14          99.12          0.88
# 6                  1600   1589    11          99.31          0.69
# 7                  1600   1580    20          98.75          1.25
# 8                  1600   1589    11          99.31          0.69
# 9                  1600   1592     8          99.50          0.50
# 10                 1600   1594     6          99.62          0.38
# 11                 1600   1589    11          99.31          0.69
# 12                 1600   1583    17          98.94          1.06
# 13                 1600   1583    17          98.94          1.06
# 14                 1600   1592     8          99.50          0.50
# 15                 1600   1587    13          99.19          0.81
# 16                 1600   1592     8          99.50          0.50
# 17                 1600   1582    18          98.88          1.12
# 18                 1600   1590    10          99.38          0.62
# 19                 1600   1589    11          99.31          0.69
# 20                 1600   1590    10          99.38          0.62
#
#                 total_records  total_goods  total_bads  percent_total_goods  \
# percentile_bin
# 1                        1600          408        1192                 0.26
# 2                        3200         1973        1227                 1.25
# 3                        4800         3552        1248                 2.25
# 4                        6400         5141        1259                 3.26
# 5                        8000         6727        1273                 4.27
# 6                        9600         8316        1284                 5.27
# 7                       11200         9896        1304                 6.27
# 8                       12800        11485        1315                 7.28
# 9                       14400        13077        1323                 8.29
# 10                      16000        14671        1329                 9.30
# 11                      17600        16260        1340                10.31
# 12                      19200        17843        1357                11.31
# 13                      20800        19426        1374                12.32
# 14                      22400        21018        1382                13.33
# 15                      24000        22605        1395                14.33
# 16                      25600        24197        1403                15.34
# 17                      27200        25779        1421                16.34
# 18                      28800        27369        1431                17.35
# 19                      30400        28958        1442                18.36
# 20                      32000        30548        1452                19.37
#
#                 percent_total_bads
# percentile_bin
# 1                            52.26
# 2                            53.79
# 3                            54.71
# 4                            55.20
# 5                            55.81
# 6                            56.29
# 7                            57.17
# 8                            57.65
# 9                            58.00
# 10                           58.26
# 11                           58.75
# 12                           59.49
# 13                           60.24
# 14                           60.59
# 15                           61.16
# 16                           61.51
# 17                           62.30
# 18                           62.74
# 19                           63.22
# 20                           63.66

# %%
generate_report(rf, x_oot, y_oot)
# Out:
#                 records  goods  bads  percent_goods  percent_bads  \
# percentile_bin
# 1                  2000    505  1495          25.25         74.75
# 2                  2000   1944    56          97.20          2.80
# 3                  2000   1975    25          98.75          1.25
# 4                  2000   1981    19          99.05          0.95
# 5                  2000   1984    16          99.20          0.80
# 6                  2000   1984    16          99.20          0.80
# 7                  2000   1982    18          99.10          0.90
# 8                  2000   1983    17          99.15          0.85
# 9                  2000   1985    15          99.25          0.75
# 10                 2000   1984    16          99.20          0.80
# 11                 2000   1979    21          98.95          1.05
# 12                 2000   1991     9          99.55          0.45
# 13                 2000   1983    17          99.15          0.85
# 14                 2000   1983    17          99.15          0.85
# 15                 2000   1987    13          99.35          0.65
# 16                 2000   1984    16          99.20          0.80
# 17                 2000   1985    15          99.25          0.75
# 18                 2000   1986    14          99.30          0.70
# 19                 2000   1981    19          99.05          0.95
# 20                 2000   1989    11          99.45          0.55
#
#                 total_records  total_goods  total_bads  percent_total_goods  \
# percentile_bin
# 1                        2000          505        1495                 0.26
# 2                        4000         2449        1551                 1.24
# 3                        6000         4424        1576                 2.24
# 4                        8000         6405        1595                 3.25
# 5                       10000         8389        1611                 4.26
# 6                       12000        10373        1627                 5.26
# 7                       14000        12355        1645                 6.27
# 8                       16000        14338        1662                 7.28
# 9                       18000        16323        1677                 8.28
# 10                      20000        18307        1693                 9.29
# 11                      22000        20286        1714                10.29
# 12                      24000        22277        1723                11.30
# 13                      26000        24260        1740                12.31
# 14                      28000        26243        1757                13.32
# 15                      30000        28230        1770                14.32
# 16                      32000        30214        1786                15.33
# 17                      34000        32199        1801                16.34
# 18                      36000        34185        1815                17.35
# 19                      38000        36166        1834                18.35
# 20                      40000        38155        1845                19.36
#
#                 percent_total_bads
# percentile_bin
# 1                            51.18
# 2                            53.10
# 3                            53.95
# 4                            54.60
# 5                            55.15
# 6                            55.70
# 7                            56.32
# 8                            56.90
# 9                            57.41
# 10                           57.96
# 11                           58.68
# 12                           58.99
# 13                           59.57
# 14                           60.15
# 15                           60.60
# 16                           61.14
# 17                           61.66
# 18                           62.14
# 19                           62.79
# 20                           63.16
