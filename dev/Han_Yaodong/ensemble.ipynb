# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from xgboost.sklearn import XGBClassifier
import matplotlib.pyplot as plt

from util import load_data, fdr, plot_report

# %%
x_train, x_test, x_oot, y_train, y_test, y_oot = load_data('var_30.csv')
x_train.head()
# Out:
#         ssn_name_count_14  ssn_name_dob_count_14  ssn_lastname_count_14  \
# 503544          -0.070962              -0.068281              -0.071051
# 400473          -0.070962              -0.068281              -0.071051
# 396977          -0.070962              -0.068281              -0.071051
# 659541          -0.070962              -0.068281              -0.071051
# 155787          -0.070962              -0.068281              -0.071051
#
#         ssn_firstname_count_14  ssn_dob_count_0_by_30  name_dob_count_0_by_30  \
# 503544               -0.071088               0.162987                0.163303
# 400473               -0.071088               0.162987                0.163303
# 396977               -0.071088               0.162987                0.163303
# 659541               -0.071088               0.162987                0.163303
# 155787               -0.071088               0.162987                0.163303
#
#         fulladdress_homephone_count_14  fulladdress_count_1_by_14  \
# 503544                       -0.070089                   0.123861
# 400473                       -0.070089                   0.123861
# 396977                       -0.070089                   0.123861
# 659541                       -0.070089                   0.123861
# 155787                       -0.070089                   0.123861
#
#         fulladdress_homephone_day_since  ssn_dob_day_since  ...  \
# 503544                         0.179929           0.172700  ...
# 400473                        -1.073225          -1.079675  ...
# 396977                        -0.190321          -0.197320  ...
# 659541                         0.721064           0.713498  ...
# 155787                        -1.035251          -1.041724  ...
#
#         fulladdress_count_0  name_dob_count_3  \
# 503544            -0.041351         -0.046415
# 400473            -0.041351         -0.046415
# 396977            -0.041351         -0.046415
# 659541            -0.041351         -0.046415
# 155787            -0.041351         -0.046415
#
#         fulladdress_homephone_count_0_by_14  name_day_since  name_count_14  \
# 503544                             0.120387        0.392219      -0.159376
# 400473                             0.120387       -0.855613      -0.159376
# 396977                             0.120387        0.023541      -0.159376
# 659541                             0.120387        0.931055      -0.159376
# 155787                             0.120387       -1.262103       1.496715
#
#         ssn_dob_count_0_by_14  ssn_lastname_count_0_by_14  \
# 503544               0.118004                    0.123458
# 400473               0.118004                    0.123458
# 396977               0.118004                    0.123458
# 659541               0.118004                    0.123458
# 155787               0.118004                    0.123458
#
#         ssn_firstname_count_0_by_14  ssn_name_day_since  address_count_1_by_7
# 503544                     0.123528            0.190461              0.103441
# 400473                     0.123528           -1.064753              0.103441
# 396977                     0.123528           -0.180397              0.103441
# 659541                     0.123528            0.732485              0.103441
# 155787                     0.123528           -1.026716              0.103441
#
# [5 rows x 30 columns]

# %%
dt = DecisionTreeClassifier(ccp_alpha=1e-07, 
                            max_depth=40, 
                            min_samples_leaf=128, 
                            class_weight=None,
                            criterion='gini')

# %%
bt = XGBClassifier(n_estimators=200,
                   max_depth=5,
                   learning_rate=0.05,
                   subsample=0.5,
                   verbose=3, n_jobs=4)

# %%
rf = RandomForestClassifier(n_estimators=700,
                            max_depth=20, 
                            max_features=8,
                            ccp_alpha=1e-6, 
                            n_jobs=4)

# %%
clfs = [('decision tree', dt), ('random forest', rf), ('boosted tree', bt)]

# %%
ensembel = VotingClassifier(clfs, voting='soft', n_jobs=2).fit(x_train, y_train)

# %%
print(fdr(ensembel, x_train, y_train))
print(fdr(ensembel, x_test, y_test))
# Out:
# 0.5455892608089261
# 0.5347483738445737
