# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_old = pd.read_csv('vars_308_old.csv')

# %%
df_old.ssn_day_since.plot(kind='line')

# %%
df_old.ssn_day_since.plot(kind='hist')

# %%
df_old['ssn_day_since'].value_counts(normalize=True)
# Out:
# 0.0      0.005127
# 1.0      0.004363
# 2.0      0.003965
# 3.0      0.003849
# 4.0      0.003778
#            ...
# 353.0    0.001994
# 355.0    0.001989
# 363.0    0.001957
# 364.0    0.001928
# 59.0     0.000743
# Name: ssn_day_since, Length: 366, dtype: float64

# %%
df = pd.read_csv('vars_308.csv')

# %%
df.ssn_day_since.plot(kind='line')

# %%
df.ssn_day_since.plot(kind='hist')

# %%
df['ssn_day_since'].value_counts(normalize=True)
# Out:
# 365.0    0.852746
# 0.0      0.002291
# 1.0      0.001649
# 2.0      0.001216
# 3.0      0.001111
#            ...
# 356.0    0.000010
# 360.0    0.000005
# 362.0    0.000003
# 363.0    0.000003
# 364.0    0.000002
# Name: ssn_day_since, Length: 366, dtype: float64
