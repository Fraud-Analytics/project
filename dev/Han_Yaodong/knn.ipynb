# %%
from collections import ChainMap
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from util import load_data, fdr, plot_report

# %%
x_train, x_test, x_oot, y_train, y_test, y_oot = load_data('var_30.csv')
x_train.head()
# Out:
#         ssn_count_3  fulladdress_count_0  address_count_0  name_dob_count_3  \
# 493455    -0.047591            -0.041351        -0.042158         -0.046415
# 278326    -0.047591            -0.041351        -0.042158         -0.046415
# 584972    -0.047591            -0.041351        -0.042158         -0.046415
# 224323    -0.047591            -0.041351        -0.042158         -0.046415
# 618423    -0.047591            -0.041351        -0.042158         -0.046415
#
#         homephone_count_14  name_dob_count_7  name_day_since  \
# 493455            0.135423         -0.055801        0.598116
# 278326           -0.437943         -0.055801        0.598116
# 584972            1.282153         -0.055801        0.598116
# 224323           -1.011308         -0.055801        0.598116
# 618423            1.282153         -0.055801       -1.406325
#
#         ssn_firstname_count_0_by_14  name_count_7  \
# 493455                     0.123528     -0.115648
# ...

# %%
knn = KNeighborsClassifier(n_jobs=8).fit(x_train, y_train)

# %%
fdr(knn, x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e14445b8b2c8> in <module>
# ----> 1 fdr(knn, x_train, y_train)
#
# ~/project/dev/Han_Yaodong/util.py in fdr(classifier, x, y, cutoff)
#      66     """Calculates FDR score for the given classifier
#      67     on dataset x and y with cutoff value."""
# ---> 68     return fdr_prob(y, classifier.predict_proba(x), cutoff)
#      69
#      70
#
# /usr/local/lib64/python3.6/site-packages/sklearn/neighbors/_classification.py in predict_proba(self, X)
#     215         X = check_array(X, accept_sparse='csr')
#     216
# --> 217         neigh_dist, neigh_ind = self.kneighbors(X)
#     218
#     219         classes_ = self.classes_
#
# /usr/local/lib64/python3.6/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     662                 delayed_query(
# ...

# %%
fdr(knn, x_test, y_test)
