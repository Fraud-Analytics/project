# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from util import load_data, fdr, plot_report
from sklearn.ensemble import BaggingClassifier

# %%
x_train, x_test, y_train, y_test = load_data('var 2000.csv')

# %%
x_train.head()
# Out:
#       ssn_name_count_14  ssn_name_dob_count_14  ssn_lastname_count_14  \
# 215           -0.070962              -0.068281              -0.071051
# 340           -0.070962              -0.068281              -0.071051
# 1062          -0.070962              -0.068281              -0.071051
# 1086          -0.070962              -0.068281              -0.071051
# 1143          -0.070962              -0.068281              -0.071051
#
#       ssn_firstname_count_14  ssn_dob_count_0_by_30  name_dob_count_0_by_30  \
# 215                -0.071088               0.162987                0.163303
# 340                -0.071088               0.162987                0.163303
# 1062               -0.071088               0.162987                0.163303
# 1086               -0.071088               0.162987                0.163303
# 1143               -0.071088               0.162987                0.163303
#
#       fulladdress_homephone_count_14  fulladdress_count_1_by_14  \
# ...

# %%
knn_clf= KNeighborsClassifier(algorithm='kd_tree',n_jobs=-1,n_neighbors=3)
knn_clf=BaggingClassifier( KNeighborsClassifier())
knn_clf.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=KNeighborsClassifier(algorithm='auto',
#                                                       leaf_size=30,
#                                                       metric='minkowski',
#                                                       metric_params=None,
#                                                       n_jobs=None,
#                                                       n_neighbors=5, p=2,
#                                                       weights='uniform'),
#                   bootstrap=True, bootstrap_features=False, max_features=1.0,
#                   max_samples=1.0, n_estimators=10, n_jobs=None,
#                   oob_score=False, random_state=None, verbose=0,
#                   warm_start=False)

# %%
print(fdr(knn_clf, x_train, y_train))
print(fdr(knn_clf, x_test, y_test))
# Out:
# 0.0
# 0.0
